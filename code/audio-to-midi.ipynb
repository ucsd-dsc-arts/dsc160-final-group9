# %%
import pafy
from IPython.display import Audio

# %%
# read in urls in python file
import audio_midi as audio

# %%
# read in urls to download
urls = audio.urls

# %%
# command line execution - video to wav format
for url in urls:
    command = 'youtube-dl --extract-audio --audio-format wav '
    a = command + url
    # !eval $a
# Out:
# [youtube] Yr2EPJxAXlQ: Downloading webpage
# [youtube] Yr2EPJxAXlQ: Downloading MPD manifest
# [dashsegments] Total fragments: 33
# [download] Destination: 重生 Reborn - 陳健安 On Chan-Yr2EPJxAXlQ.webm
# [download] 100% of 5.91MiB in 00:088.49KiB/s ETA 00:0065
# [ffmpeg] Destination: 重生 Reborn - 陳健安 On Chan-Yr2EPJxAXlQ.wav
# Deleting original file 重生 Reborn - 陳健安 On Chan-Yr2EPJxAXlQ.webm (pass -k to keep)
# [youtube] VqKRYpArttI: Downloading webpage
# [youtube] VqKRYpArttI: Downloading MPD manifest
# [dashsegments] Total fragments: 21
# [download] Destination: 李浩然 - 一千零一次我愛你『今天為止想了你一千天，愛你的話也說了一千遍.』(Piano Tutorial Synthesia)-VqKRYpArttI.webm
# [download] 100% of 3.50MiB in 00:0410.43KiB/s ETA 00:00
# [ffmpeg] Destination: 李浩然 - 一千零一次我愛你『今天為止想了你一千天，愛你的話也說了一千遍.』(Piano Tutorial Synthesia)-VqKRYpArttI.wav
# Deleting original file 李浩然 - 一千零一次我愛你『今天為止想了你一千天，愛你的話也說了一千遍.』(Piano Tutorial Synthesia)-VqKRYpArttI.webm (pass -k to keep)
# [BiliBili] 41048045: Downloading webpage
# ...

# %%
files = !ls
print('Number of mp3 files downloaded: {}'.format(len(files)-3))
# Out:
# Number of mp3 files downloaded: 65

# %%
! youtube-dl --extract-audio --audio-format wav https://www.youtube.com/watch?v=gGYz7qS80Ms
# Out:
# [youtube] gGYz7qS80Ms: Downloading webpage
# [download] Destination: 那女孩對我說 鋼琴版 (主唱 - 黃義達 (Uu COVER VER) )-gGYz7qS80Ms.webm
# [download] 100% of 4.79MiB in 00:0106MiB/s ETA 00:008
# [ffmpeg] Destination: 那女孩對我說 鋼琴版 (主唱 - 黃義達 (Uu COVER VER) )-gGYz7qS80Ms.wav
# Deleting original file 那女孩對我說 鋼琴版 (主唱 - 黃義達 (Uu COVER VER) )-gGYz7qS80Ms.webm (pass -k to keep)

# %%
wav[0][:-4] in
# Out:
# '123我愛你'

# %%
# command line execution - wavs to midi
for audio in audios:
    command = 'audio-to-midi' + audio + 'time-window 5 --activation-level 0.0'
    # !eval $command
